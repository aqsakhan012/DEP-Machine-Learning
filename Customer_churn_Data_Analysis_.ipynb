# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset = pd.read_csv('customerchurn.csv')

# %%
# print the dataset
dataset
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
dataset.shape
# Out:
# (7043, 21)

# %%
 # checking the descriptive statistics of the dataset
dataset.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
dataset.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# checking the datatypes of the columns
dataset.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Checking the null values in the dataset
dataset.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
dataset
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# checking the duplicated dataset
dataset.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,8))
dataset['Churn'].value_counts().plot(kind='bar')
plt.title('Churn Distribution')
plt.xlabel('Count')
plt.ylabel('Target Variable')
plt.show()

# %%
dataset['Churn'].value_counts()/len(dataset['Churn'])*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %%
dataset_customer = dataset.copy()

# %%
dataset.TotalCharges = pd.to_numeric(dataset.TotalCharges, errors='coerce')

# %%
dataset.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
dataset.loc[dataset['TotalCharges'].isnull() == True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
dataset.dropna(inplace= True)

# %%
dataset.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
dataset.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
dataset['tenure'].max()
# Out:
# 72

# %%
values = ["{0} -{1}" .format(j ,j+11) for j in range(1, 72 ,12) ]
dataset['tenure_group'] = pd.cut(dataset['tenure'], range(0, 80, 12), labels=values)

# %%
dataset['tenure_group'].value_counts()
# Out:
# tenure_group
# 1 -12     2175
# 61 -72    1407
# 13 -24    1024
# 25 -36     832
# 49 -60     832
# 37 -48     762
# Name: count, dtype: int64

# %%
dataset.drop('tenure', axis=1, inplace=True)
dataset.drop('customerID', axis=1, inplace=True)

# %%
dataset.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
for i ,predictor in enumerate (dataset.drop(columns=['Churn','TotalCharges','MonthlyCharges',])):
    plt.figure(i)
    sns.countplot(data=dataset, x=predictor, hue='Churn')

# %%
dataset['Churn'] = np.where(dataset.Churn == 'Yes',1,0)

# %%
dataset.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
dataset_dumies = pd.get_dummies(dataset).astype(int)

# %%
dataset_dumies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0              29            29      0              1
# 1              0              56          1889      0              0
# 2              0              53           108      1              0
# 3              0              42          1840      0              0
# 4              0              70           151      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %%
import seaborn as sns

# %%
sns.lmplot(x='MonthlyCharges', y='TotalCharges', data=dataset_dumies ,fit_reg=False )

# %%
dataset_math = sns.kdeplot(dataset_dumies.MonthlyCharges[(dataset_dumies["Churn"] == 1) ],
                           color = "Green" , shade = True)
dataset_math = sns.kdeplot(dataset_dumies.MonthlyCharges[(dataset_dumies["Churn"] == 0) ],
                           color = "Blue" , shade = True)
dataset_math.legend("No_Churn","Churn" ,loc = 'upper right')
dataset_math.set_ylabel('Density')
dataset_math.set_xlabel('MonthlyCharges')
dataset_math.set_title('MonthlyCharges by Churn')
# Out:
# <ipython-input-248-5528dd4dd97d>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   dataset_math = sns.kdeplot(dataset_dumies.MonthlyCharges[(dataset_dumies["Churn"] == 1) ],
# <ipython-input-248-5528dd4dd97d>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   dataset_math = sns.kdeplot(dataset_dumies.MonthlyCharges[(dataset_dumies["Churn"] == 0) ],
# <ipython-input-248-5528dd4dd97d>:5: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   dataset_math.legend("No_Churn","Churn" ,loc = 'upper right')
# Text(0.5, 1.0, 'MonthlyCharges by Churn')

# %%
dataset_T = sns.kdeplot(dataset_dumies.TotalCharges[(dataset_dumies["Churn"] == 1) ],
                           color = "Green" , shade = True)
dataset_T = sns.kdeplot(dataset_dumies.TotalCharges[(dataset_dumies["Churn"] == 0) ],
                           color = "Blue" , shade = True)
dataset_T.legend("Churn_No","Churn")
dataset_T.set_ylabel('Density')
dataset_T.set_xlabel('TotalCharges')
dataset_T.set_title('TotalCharges by Churn')
# Out:
# <ipython-input-249-2bdc8cd16efb>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   dataset_T = sns.kdeplot(dataset_dumies.TotalCharges[(dataset_dumies["Churn"] == 1) ],
# <ipython-input-249-2bdc8cd16efb>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   dataset_T = sns.kdeplot(dataset_dumies.TotalCharges[(dataset_dumies["Churn"] == 0) ],
# <ipython-input-249-2bdc8cd16efb>:5: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   dataset_T.legend("Churn_No","Churn")
# Text(0.5, 1.0, 'TotalCharges by Churn')

# %%
plt.figure(figsize=(20,8))
dataset_dumies.corr()['Churn'].sort_values(ascending=False).plot(kind='bar')
plt.title('Correlation with Churn')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dataset_dumies.corr(), cmap = "Paired")
plt.title('Correlation Heatmap')
plt.show()

# %%
dataset_target0 = dataset.loc[dataset["Churn"]==0]
dataset_target1 = dataset.loc[dataset["Churn"]==1]

# %%
def uniplot(df,col,title,hue=None):


  sns.set_style('whitegrid')
  sns.set_context('talk')
  plt.rcParams['axes.labelsize'] = 22
  plt.rcParams['axes.titlesize'] = 15
  plt.rcParams['axes.titlepad'] = 30
  temp = pd.Series(data = hue)
  fig, ax = plt.subplots()
  width = len(df[col].unique()) + 7 + 4*len(temp.unique())
  fig.set_size_inches(width , 8)
  plt.xticks(rotation = 45)
  plt.yscale('log')
  plt.title(title)
  ax = sns.countplot(data = df , x = col , order = df[col].value_counts().index ,hue = hue , palette = 'bright')


  plt.show()

# %%
uniplot(dataset_target1, col = 'Partner', title = 'Distribution of gender where Churners',hue = 'gender')

# %%
uniplot(dataset_target0, col = 'Partner', title = 'Distribution of gender where NON_Churners',hue = 'gender')

# %%
uniplot(dataset_target1, col = 'PaymentMethod', title = 'Distribution of gender where Churners',hue = 'gender')

# %%
uniplot(dataset_target1, col = 'Contract', title = 'Distribution of gender where Churners',hue = 'gender')

# %%
dataset_dumies.to_csv('customer_churn.csv', index=False)
